# %% [markdown]
# <a href="https://colab.research.google.com/github/aayush010/kaggle/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install papermill
# Out:
# ...
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/papermill/iorw.py in read(self, path)
#     198                 # string
# --> 199                 json.loads(path)
#     200                 return path
#
# /usr/lib/python3.12/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# /usr/lib/python3.12/json/decoder.py in decode(self, s, _w)
#     337         """
# --> 338         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     339         end = _w(s, end).end()
#
# /usr/lib/python3.12/json/decoder.py in raw_decode(self, s, idx)
#     355         except StopIteration as err:
# ...

# %%
import papermill as pm

# Define parameter values to pass
params = {
    "param1": "titanic"
}

# Execute notebook_B.ipynb with parameters
pm.execute_notebook(
    'kaggle_data.ipynb',      # input notebook
    'notebook_B_output.ipynb',  # output notebook (with results)
    parameters=params
)

print("✅ notebook_B executed successfully!")

# You can read the file or outputs generated by notebook_B
with open("output_from_B.txt") as f:
    output = f.read()

print("📤 Output from notebook_B:", output)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/papermill/iorw.py in read(self, path)
#     198                 # string
# --> 199                 json.loads(path)
#     200                 return path
#
# /usr/lib/python3.12/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# /usr/lib/python3.12/json/decoder.py in decode(self, s, _w)
#     337         """
# --> 338         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     339         end = _w(s, end).end()
#
# /usr/lib/python3.12/json/decoder.py in raw_decode(self, s, idx)
#     355         except StopIteration as err:
# ...
